# %%
# Data Exploration Notebook Content

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv('../data/raw/synthetic_debt_data.csv')

# Display the first few rows of the dataframe
print(df.head())

# Get a concise summary of the dataframe
print(df.info())

# Describe the data to get mean, median, etc.
print(df.describe())
# Out:
#    User_ID  Initial_Debt  Interest_Rate  Minimum_Payment_Percentage  \
# 0        1      38079.47          17.76                    2.559374
# 1        2      95120.72          22.15                    2.076951
# 2        3      73467.40           4.35                    2.196458
# 3        4      60267.19           4.87                    2.293020
# 4        5      16445.85          24.67                    2.695851
#
#    Monthly_Income  Monthly_Expenses  Additional_Payment Repayment_Strategy
# 0         5402.17         3457.3888              518.61           Snowball
# 1         5210.72         4064.3616              137.91           Snowball
# 2        13781.31        10473.7956              697.92           Snowball
# 3         5244.10         2045.1990              490.49   Highest Interest
# 4         5535.35         2158.7865              125.76          Avalanche
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     2000 non-null   int64
#  1   Initial_Debt                2000 non-null   float64
#  2   Interest_Rate               2000 non-null   float64
#  3   Minimum_Payment_Percentage  2000 non-null   float64
#  4   Monthly_Income              2000 non-null   float64
#  5   Monthly_Expenses            2000 non-null   float64
#  6   Additional_Payment          2000 non-null   float64
#  7   Repayment_Strategy          2000 non-null   object
# dtypes: float64(6), int64(1), object(1)
# memory usage: 125.1+ KB
# None
#            User_ID  Initial_Debt  Interest_Rate  Minimum_Payment_Percentage  \
# count  2000.000000   2000.000000    2000.000000                 2000.000000
# mean   1000.500000  50365.056015      16.330400                    2.497936
# std     577.494589  28928.869021       7.811433                    0.490241
# min       1.000000   1318.610000       3.010000                    1.500000
# 25%     500.750000  24566.605000       9.847500                    2.142129
# 50%    1000.500000  51227.780000      16.245000                    2.508418
# 75%    1500.250000  75317.205000      22.897500                    2.839651
# max    2000.000000  99972.050000      29.990000                    3.500000
#
#        Monthly_Income  Monthly_Expenses  Additional_Payment
# count     2000.000000       2000.000000         2000.000000
# mean      8453.075050       5064.070868          390.271860
# std       3751.538569       2759.244265          229.851399
# min       2000.150000        696.884400            0.190000
# 25%       5260.227500       2810.447625          191.467500
# 50%       8405.025000       4630.175650          387.360000
# 75%      11732.977500       6925.989525          589.710000
# max      14994.250000      13198.077000          799.570000

# %%
# Visualization of the distribution of Initial Debt
df['Initial_Debt'].hist(bins=50)
plt.title('Distribution of Initial Debt')
plt.xlabel('Initial Debt')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot for visualizing Monthly Expenses
sns.boxplot(x=df['Monthly_Expenses'])
plt.title('Box Plot of Monthly Expenses')
plt.xlabel('Monthly Expenses')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Scatter plot for Initial Debt vs. Additional Payment
plt.scatter(df['Initial_Debt'], df['Additional_Payment'])
plt.title('Initial Debt vs. Additional Payment')
plt.xlabel('Initial Debt')
plt.ylabel('Additional Payment')
plt.show()

# %%
# Plotting the correlation matrix of numeric features
numeric_df = df.select_dtypes(include=[np.number])
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Count plot of repayment strategies
sns.countplot(x='Repayment_Strategy', data=df)
plt.title('Distribution of Repayment Strategies')
plt.xlabel('Repayment Strategy')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
